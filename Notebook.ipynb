# %%
import pandas as pd

# %%
data = pd.read_csv("HR-Employee-Attrition.csv")

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
columns_to_keep = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
              'YearsWithCurrManager']
columns_to_drop = [
       'EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender','JobInvolvement', 'JobLevel','JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       ]

# %%
len(columns_to_keep)
# Out:
# 13

# %%
len(columns_to_drop)
# Out:
# 22

# %%
data.drop(columns = columns_to_drop, inplace = True)

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.head(3).iloc[ :,4:10]
# Out:
#                Department  DistanceFromHome  Education  HourlyRate  \
# 0                   Sales                 1          2          94
# 1  Research & Development                 8          1          61
# 2  Research & Development                 2          2          92
#
#                  JobRole  YearsAtCompany
# 0        Sales Executive               6
# 1     Research Scientist              10
# 2  Laboratory Technician               0

# %%
data.shape
# Out:
# (1470, 13)

# %%
data[['Age', 'Attrition']]
# Out:
#       Age Attrition
# 0      41       Yes
# 1      49        No
# 2      37       Yes
# 3      33        No
# 4      27        No
# ...   ...       ...
# 1465   36        No
# 1466   39        No
# 1467   27        No
# 1468   49        No
# 1469   34        No
#
# [1470 rows x 2 columns]

# %% [markdown]
# # 1st Method

# %%
new_data = data[columns_to_keep]

# %% [markdown]
# # 2nd Method

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  HourlyRate                    JobRole  \
# ...

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  HourlyRate                    JobRole  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'HourlyRate', 'JobRole',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data = data.rename(columns = {"DistanceFromHome": "DistanceHome"})

# %%
data = data.rename(columns = {"DailyRate": "DailyWage", "HourlyRate": "HourlyWage"})

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyWage', 'Department',
#        'DistanceHome', 'Education', 'HourlyWage', 'JobRole', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
data.duplicated().value_counts()
# Out:
# False    1470
# Name: count, dtype: int64

# %%
type(data.duplicated())
# Out:
# pandas.core.series.Series

# %%
data.drop_duplicates(inplace = True)

# %%
data.shape
# Out:
# (1470, 13)

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %%
data[data["Attrition"] == "Yes"]["Attrition"].unique()
# Out:
# array(['Yes'], dtype=object)

# %%
type(data["BusinessTravel"][1])
# Out:
# str

# %%
modify_data = data.copy()

# %%
modify_data
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %%
data["BusinessTravel"] = data["BusinessTravel"].str.replace("_"," ")

# %%
modify_data
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %% [markdown]
# # remove Nan values

# %% [markdown]
# data.isna().sum()

# %%
data.isna().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# DailyWage                  0
# Department                 0
# DistanceHome               0
# Education                  0
# HourlyWage                 0
# JobRole                    0
# YearsAtCompany             0
# YearsInCurrentRole         0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data = data.dropna()

# %%
data
# Out:
#       Age Attrition     BusinessTravel  DailyWage              Department  \
# 0      41       Yes      Travel Rarely       1102                   Sales
# 1      49        No  Travel Frequently        279  Research & Development
# 2      37       Yes      Travel Rarely       1373  Research & Development
# 3      33        No  Travel Frequently       1392  Research & Development
# 4      27        No      Travel Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel Frequently        884  Research & Development
# 1466   39        No      Travel Rarely        613  Research & Development
# 1467   27        No      Travel Rarely        155  Research & Development
# 1468   49        No  Travel Frequently       1023                   Sales
# 1469   34        No      Travel Rarely        628  Research & Development
#
#       DistanceHome  Education  HourlyWage                    JobRole  \
# ...

# %%
data["Attrition"] = data["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
data
# Out:
#       Age  Attrition     BusinessTravel  DailyWage              Department  \
# 0      41          1      Travel Rarely       1102                   Sales
# 1      49          0  Travel Frequently        279  Research & Development
# 2      37          1      Travel Rarely       1373  Research & Development
# 3      33          0  Travel Frequently       1392  Research & Development
# 4      27          0      Travel Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel Frequently        884  Research & Development
# 1466   39          0      Travel Rarely        613  Research & Development
# 1467   27          0      Travel Rarely        155  Research & Development
# 1468   49          0  Travel Frequently       1023                   Sales
# 1469   34          0      Travel Rarely        628  Research & Development
#
# ...

# %%
data.to_csv("HR-Employee-Attrition-Cleaned.csv", index = False)

# %%
data.to_excel("HR-Employee-Attrition-Cleaned.xlsx", index = False)

# %%
pd.read_csv("HR-Employee-Attrition-Cleaned.csv")
# Out:
#       Age  Attrition     BusinessTravel  DailyWage              Department  \
# 0      41          1      Travel Rarely       1102                   Sales
# 1      49          0  Travel Frequently        279  Research & Development
# 2      37          1      Travel Rarely       1373  Research & Development
# 3      33          0  Travel Frequently       1392  Research & Development
# 4      27          0      Travel Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel Frequently        884  Research & Development
# 1466   39          0      Travel Rarely        613  Research & Development
# 1467   27          0      Travel Rarely        155  Research & Development
# 1468   49          0  Travel Frequently       1023                   Sales
# 1469   34          0      Travel Rarely        628  Research & Development
#
# ...

# %%
pd.read_excel("HR-Employee-Attrition-Cleaned.xlsx")
# Out:
#       Age  Attrition     BusinessTravel  DailyWage              Department  \
# 0      41          1      Travel Rarely       1102                   Sales
# 1      49          0  Travel Frequently        279  Research & Development
# 2      37          1      Travel Rarely       1373  Research & Development
# 3      33          0  Travel Frequently       1392  Research & Development
# 4      27          0      Travel Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel Frequently        884  Research & Development
# 1466   39          0      Travel Rarely        613  Research & Development
# 1467   27          0      Travel Rarely        155  Research & Development
# 1468   49          0  Travel Frequently       1023                   Sales
# 1469   34          0      Travel Rarely        628  Research & Development
#
# ...
